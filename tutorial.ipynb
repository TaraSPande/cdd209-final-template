# %% [markdown]
# # Pharma Medication Adherence Package Tutorial

# %%
from pharma_adherence import ModelTrainer, PharmaDataset

# %% [markdown]
# ### Data Cleaning
# talk about data cleaning

# %%
dataset = PharmaDataset("data/raw/prescriptions_large_raw.csv")
print(dataset.df.head())
# Out:
#   patient_id    fill_date         drug_name days_supply  quantity_dispensed  \
# 0       P001   2024-12-30       amoxicillin          60                  60
# 1       P001  Jan 26 2025      PANTOPRAZOLE          60                 120
# 2       P001  Mar 02 2025    AMLODIPINE 5MG      30days                  30
# 3       P001   2025-04-04     Metformin HCl     90 days                  90
# 4       P002   12/30/2024  Albuterol 180mcg     90 days                  30
#
#    refill_number  patient_age sex  zip_code prescriber_id       pharmacy_name  \
# 0            0.0           34   f   94720.0          D123  walgreens pharmacy
# 1            NaN           34   f   94720.0          D208        csv pharmacy
# 2            NaN           34   f   94720.0          D217           Walgreens
# 3            3.0           34   f   94720.0          D159          CSV #13239
# 4            NaN           40   F   90210.0          D197    Walgreens #83887
#
# ...
